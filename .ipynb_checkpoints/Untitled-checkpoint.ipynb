# %%
import pandas as pd
import copy
import warnings
import datetime as dt
import numpy as np

# %%
driver_history_df = pd.read_csv("./f1db_csv/driver_history.csv")

# %%
# Function that chooses race history for a particular driver
def driver_history_selection(driver_name):
    driver_table = driver_history_df[driver_history_df.driverName == driver_name]
    driver_table = driver_table.sort_values("date", ascending = False)
    return driver_table

driver1_df = driver_history_selection("Lewis Hamilton")
# Out:
#       Unnamed: 0      driverName  number nationality  year  \
# 7033        7033  Lewis Hamilton    44.0     British  2021
# 7013        7013  Lewis Hamilton    44.0     British  2021
# 6993        6993  Lewis Hamilton    44.0     British  2021
# 6974        6974  Lewis Hamilton    44.0     British  2021
# 6954        6954  Lewis Hamilton    44.0     British  2021
# ...          ...             ...     ...         ...   ...
# 428          428  Lewis Hamilton    44.0     British  2007
# 406          406  Lewis Hamilton    44.0     British  2007
# 385          385  Lewis Hamilton    44.0     British  2007
# 365          365  Lewis Hamilton    44.0     British  2007
# 348          348  Lewis Hamilton    44.0     British  2007
#
#                        name        date  raceId constructorName  position  \
# 7033     Styrian Grand Prix  2021-06-27    1058        Mercedes         3
# 7013      French Grand Prix  2021-06-20    1059        Mercedes         2
# ...
